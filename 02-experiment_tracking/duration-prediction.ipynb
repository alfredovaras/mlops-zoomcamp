# %%
# !python -V
# Out:
# Python 3.9.17

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np

# %%
import pickle

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge

from sklearn.metrics import mean_squared_error

# %%
import mlflow
mlflow.set_tracking_uri("sqlite:///mlflow.db")
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# INFO  [alembic.runtime.migration] Context impl SQLiteImpl.
# INFO  [alembic.runtime.migration] Will assume non-transactional DDL.
# 2024/12/25 17:51:38 INFO mlflow.tracking.fluent: Experiment with name 'nyc-taxi-experiment' does not exist. Creating a new experiment.
# <Experiment: artifact_location='/Users/luisvaras/code/zoomcamp/mlops-zoomcamp/03-training/experiment_tracking/mlruns/1', creation_time=1735159898745, experiment_id='1', last_update_time=1735159898745, lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %%
df = pd.read_parquet('./data/green_tripdata_2021-01.parquet')

df.lpep_dropoff_datetime - df.lpep_pickup_datetime

df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

df = df[(df.duration >= 1) & (df.duration <=60)]

cat = ['PULocationID', 'DOLocationID']
num = ['trip_distance']

df[cat] = df[cat].astype(str)

# %%
# df
sns.distplot(df.duration)
# Out:
# /home/codespace/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='duration', ylabel='Density'>

# %%
# convert DF to Dictionary
# df[cat + num].iloc[:10].to_dict(orient='records')
train_dicts = df[cat + num].to_dict(orient='records')

dv = DictVectorizer()
X_train = dv.fit_transform(train_dicts)

target = 'duration'
y_train = df[target].values

lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_train)

mse = mean_squared_error(y_train, y_pred) #, squared=False)
rmse = np.sqrt(mse)

# %%
sns.distplot(y_pred, label='prediction')
sns.distplot(y_train, label='actual')
plt.legend()

# %%
def read_dataframe(filename):
    df = pd.read_parquet(filename)

    df['duration'] = df.lpep_dropoff_datetime - df.lpep_pickup_datetime
    df.duration = df.duration.apply(lambda td: td.total_seconds() / 60)

    df = df[(df.duration >= 1) & (df.duration <=60)]

    cat = ['PULocationID', 'DOLocationID']
    df[cat] = df[cat].astype(str)

    return df

# %%
df_train = read_dataframe('./data/green_tripdata_2021-01.parquet')
df_val = read_dataframe('./data/green_tripdata_2021-02.parquet')

# %%
len(df_train), len(df_val)
# Out:
# (73908, 61921)

# %%
df_train['PU_DO'] = df_train['PULocationID'] + '_' + df_train['DOLocationID']
df_val['PU_DO'] = df_val['PULocationID'] + '_' + df_val['DOLocationID']

# %%
cat = ['PU_DO'] #['PULocationID', 'DOLocationID']
num = ['trip_distance']

dv = DictVectorizer()

train_dicts = df_train[cat + num].to_dict(orient='records')
X_train = dv.fit_transform(train_dicts)

val_dicts = df_val[cat + num].to_dict(orient='records')
X_val = dv.transform(val_dicts)

# %%
target = 'duration'
y_train = df_train[target].values
y_val = df_val[target].values

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_val)

#mean_squared_error(y_val, y_pred, squared=False)
mse = mean_squared_error(y_val, y_pred) #, squared=False)
rmse = np.sqrt(mse)
print(f'RMSE: {rmse:.2f}')
# Out:
# RMSE: 7.76

# %%
with open('models/lin_reg.bin', 'wb') as f_out:
    pickle.dump((dv, lr), f_out)

# %%
with mlflow.start_run():

    mlflow.set_tag("developer", "luis")
    mlflow.log_param("train-data-path", './data/green_tripdata_2021-01.parquet')
    mlflow.log_param("val-data-path", './data/green_tripdata_2021-02.parquet')

    alpha = 0.1
    mlflow.log_param("alpha", alpha)

    lr = Lasso(alpha)
    lr.fit(X_train, y_train)

    y_pred = lr.predict(X_val)

    #mean_squared_error(y_val, y_pred, squared=False)
    mse = mean_squared_error(y_val, y_pred) #, squared=False)
    rmse = np.sqrt(mse)
    mlflow.log_metric("rmse", rmse)

    mlflow.log_artifact(local_path='models/lin_reg.bin', artifact_path='models_pickle')

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

# %%
train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        mse = mean_squared_error(y_val, y_pred) #, squared=False)
        rmse = np.sqrt(mse)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42,
}

best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=10,
    trials=Trials()

)
# Out:
# [0]	validation-rmse:8.49781
# [1]	validation-rmse:7.17193
# [2]	validation-rmse:6.73345
# [3]	validation-rmse:6.57592
# [4]	validation-rmse:6.50861
# [5]	validation-rmse:6.48066
# [6]	validation-rmse:6.45617
# [7]	validation-rmse:6.44290
# [8]	validation-rmse:6.43776
# [9]	validation-rmse:6.43271
# [10]	validation-rmse:6.42896
# [11]	validation-rmse:6.42452
# [12]	validation-rmse:6.41868
# [13]	validation-rmse:6.41488
# [14]	validation-rmse:6.41052
# [15]	validation-rmse:6.40751
# [16]	validation-rmse:6.40484
# [17]	validation-rmse:6.40347
# [18]	validation-rmse:6.39845
# [19]	validation-rmse:6.39603
# [20]	validation-rmse:6.39398
# [21]	validation-rmse:6.39171
# [22]	validation-rmse:6.38840
# [23]	validation-rmse:6.38623
# [24]	validation-rmse:6.38325
# [25]	validation-rmse:6.38065
# [26]	validation-rmse:6.37983
# [27]	validation-rmse:6.37647
# [28]	validation-rmse:6.37435
# [29]	validation-rmse:6.37246
# [30]	validation-rmse:6.36992
# [31]	validation-rmse:6.36800
# [32]	validation-rmse:6.36687
# [33]	validation-rmse:6.36443
# [34]	validation-rmse:6.36390
# [35]	validation-rmse:6.36270
# [36]	validation-rmse:6.36050
# [37]	validation-rmse:6.35912
# [38]	validation-rmse:6.35612
# [39]	validation-rmse:6.35566
# [40]	validation-rmse:6.35496
# [41]	validation-rmse:6.35350
# [42]	validation-rmse:6.35169
# [43]	validation-rmse:6.34957
# [44]	validation-rmse:6.34842
# [45]	validation-rmse:6.34771
# [46]	validation-rmse:6.34538
# [47]	validation-rmse:6.34478
# [48]	validation-rmse:6.34384
# [49]	validation-rmse:6.34376
# [50]	validation-rmse:6.34314
# [51]	validation-rmse:6.34271
# [52]	validation-rmse:6.34276
# [53]	validation-rmse:6.34183
# [54]	validation-rmse:6.34066
# [55]	validation-rmse:6.33976
# [56]	validation-rmse:6.34000
# [57]	validation-rmse:6.33742
# [58]	validation-rmse:6.33537
# [59]	validation-rmse:6.33508
# [60]	validation-rmse:6.33459
# [61]	validation-rmse:6.33383
# [62]	validation-rmse:6.33196
# [63]	validation-rmse:6.33068
# [64]	validation-rmse:6.33088
# [65]	validation-rmse:6.33078
# [66]	validation-rmse:6.33060
# [67]	validation-rmse:6.33062
# [68]	validation-rmse:6.33000
# [69]	validation-rmse:6.32937
# [70]	validation-rmse:6.32872
# [71]	validation-rmse:6.32617
# [72]	validation-rmse:6.32688
# [73]	validation-rmse:6.32690
# [74]	validation-rmse:6.32665
# [75]	validation-rmse:6.32665
# [76]	validation-rmse:6.32656
# [77]	validation-rmse:6.32592
# [78]	validation-rmse:6.32479
# [79]	validation-rmse:6.32432
# [80]	validation-rmse:6.32358
# [81]	validation-rmse:6.32274
# [82]	validation-rmse:6.32222
# [83]	validation-rmse:6.32271
# [84]	validation-rmse:6.32343
# [85]	validation-rmse:6.32325
# [86]	validation-rmse:6.32319
# [87]	validation-rmse:6.32222
# [88]	validation-rmse:6.32078
# [89]	validation-rmse:6.32156
# [90]	validation-rmse:6.32173
# [91]	validation-rmse:6.32184
# [92]	validation-rmse:6.32155
# [93]	validation-rmse:6.32158
# [94]	validation-rmse:6.32100
# [95]	validation-rmse:6.32249
# [96]	validation-rmse:6.32254
# [97]	validation-rmse:6.32250
# [98]	validation-rmse:6.32354
# [99]	validation-rmse:6.32351
# [100]	validation-rmse:6.32300
# [101]	validation-rmse:6.32381
# [102]	validation-rmse:6.32351
# [103]	validation-rmse:6.32404
# [104]	validation-rmse:6.32216
# [105]	validation-rmse:6.32233
# [106]	validation-rmse:6.32264
# [107]	validation-rmse:6.32249
# [108]	validation-rmse:6.32232
# [109]	validation-rmse:6.32240
# [110]	validation-rmse:6.32331
# [111]	validation-rmse:6.32421
# [112]	validation-rmse:6.32505
# [113]	validation-rmse:6.32563
# [114]	validation-rmse:6.32589
# [115]	validation-rmse:6.32548
# [116]	validation-rmse:6.32506
# [117]	validation-rmse:6.32503
# [118]	validation-rmse:6.32600
# [119]	validation-rmse:6.32596
# [120]	validation-rmse:6.32654
# [121]	validation-rmse:6.32666
# [122]	validation-rmse:6.32762
# [123]	validation-rmse:6.32736
# [124]	validation-rmse:6.32764
# [125]	validation-rmse:6.32724
# [126]	validation-rmse:6.32708
# [127]	validation-rmse:6.32720
# [128]	validation-rmse:6.32751
# [129]	validation-rmse:6.32878
# [130]	validation-rmse:6.32882
# [131]	validation-rmse:6.32934
# [132]	validation-rmse:6.32918
# [133]	validation-rmse:6.32896
# [134]	validation-rmse:6.32922
# [135]	validation-rmse:6.32903
# [136]	validation-rmse:6.32835
# [137]	validation-rmse:6.32837
# [0]	validation-rmse:11.57002
# [1]	validation-rmse:10.99395
# [2]	validation-rmse:10.47869
# [3]	validation-rmse:10.01984
# [4]	validation-rmse:9.61240
# [5]	validation-rmse:9.25110
# [6]	validation-rmse:8.93014
# [7]	validation-rmse:8.64691
# [8]	validation-rmse:8.39776
# [9]	validation-rmse:8.17894
# [10]	validation-rmse:7.98667
# [11]	validation-rmse:7.81857
# [12]	validation-rmse:7.67180
# [13]	validation-rmse:7.54342
# [14]	validation-rmse:7.43053
# [15]	validation-rmse:7.33186
# [16]	validation-rmse:7.24564
# [17]	validation-rmse:7.17091
# [18]	validation-rmse:7.10523
# [19]	validation-rmse:7.04738
# [20]	validation-rmse:6.99696
# [21]	validation-rmse:6.95264
# [22]	validation-rmse:6.91402
# [23]	validation-rmse:6.88008
# [24]	validation-rmse:6.85028
# [25]	validation-rmse:6.82385
# [26]	validation-rmse:6.80004
# [27]	validation-rmse:6.77872
# [28]	validation-rmse:6.76034
# [29]	validation-rmse:6.74393
# [30]	validation-rmse:6.72907
# [31]	validation-rmse:6.71616
# [32]	validation-rmse:6.70415
# [33]	validation-rmse:6.69385
# [34]	validation-rmse:6.68428
# [35]	validation-rmse:6.67582
# [36]	validation-rmse:6.66817
# [37]	validation-rmse:6.66112
# [38]	validation-rmse:6.65492
# [39]	validation-rmse:6.64933
# [40]	validation-rmse:6.64375
# [41]	validation-rmse:6.63927
# [42]	validation-rmse:6.63465
# [43]	validation-rmse:6.63015
# [44]	validation-rmse:6.62642
# [45]	validation-rmse:6.62271
# [46]	validation-rmse:6.61907
# [47]	validation-rmse:6.61601
# [48]	validation-rmse:6.61270
# [49]	validation-rmse:6.60991
# [50]	validation-rmse:6.60762
# [51]	validation-rmse:6.60562
# [52]	validation-rmse:6.60340
# [53]	validation-rmse:6.60150
# [54]	validation-rmse:6.59946
# [55]	validation-rmse:6.59772
# [56]	validation-rmse:6.59612
# [57]	validation-rmse:6.59486
# [58]	validation-rmse:6.59355
# [59]	validation-rmse:6.59157
# [60]	validation-rmse:6.59048
# [61]	validation-rmse:6.58898
# [62]	validation-rmse:6.58825
# [63]	validation-rmse:6.58687
# [64]	validation-rmse:6.58590
# [65]	validation-rmse:6.58542
# [66]	validation-rmse:6.58419
# [67]	validation-rmse:6.58310
# [68]	validation-rmse:6.58191
# [69]	validation-rmse:6.58122
# [70]	validation-rmse:6.58066
# [71]	validation-rmse:6.58020
# [72]	validation-rmse:6.57984
# [73]	validation-rmse:6.57926
# [74]	validation-rmse:6.57860
# [75]	validation-rmse:6.57773
# [76]	validation-rmse:6.57714
# [77]	validation-rmse:6.57656
# [78]	validation-rmse:6.57572
# [79]	validation-rmse:6.57477
# [80]	validation-rmse:6.57404
# [81]	validation-rmse:6.57346
# [82]	validation-rmse:6.57263
# [83]	validation-rmse:6.57203
# [84]	validation-rmse:6.57165
# [85]	validation-rmse:6.57119
# [86]	validation-rmse:6.57093
# [87]	validation-rmse:6.57049
# [88]	validation-rmse:6.57007
# [89]	validation-rmse:6.56940
# [90]	validation-rmse:6.56890
# [91]	validation-rmse:6.56841
# [92]	validation-rmse:6.56818
# [93]	validation-rmse:6.56760
# [94]	validation-rmse:6.56684
# [95]	validation-rmse:6.56617
# [96]	validation-rmse:6.56576
# [97]	validation-rmse:6.56508
# [98]	validation-rmse:6.56467
# [99]	validation-rmse:6.56419
# [100]	validation-rmse:6.56379
# [101]	validation-rmse:6.56339
# [102]	validation-rmse:6.56318
# [103]	validation-rmse:6.56293
# [104]	validation-rmse:6.56237
# [105]	validation-rmse:6.56184
# [106]	validation-rmse:6.56141
# [107]	validation-rmse:6.56091
# [108]	validation-rmse:6.56054
# [109]	validation-rmse:6.55998
# [110]	validation-rmse:6.55974
# [111]	validation-rmse:6.55938
# [112]	validation-rmse:6.55899
# [113]	validation-rmse:6.55850
# [114]	validation-rmse:6.55831
# [115]	validation-rmse:6.55780
# [116]	validation-rmse:6.55708
# [117]	validation-rmse:6.55668
# [118]	validation-rmse:6.55624
# [119]	validation-rmse:6.55579
# [120]	validation-rmse:6.55558
# [121]	validation-rmse:6.55535
# [122]	validation-rmse:6.55506
# [123]	validation-rmse:6.55489
# [124]	validation-rmse:6.55466
# [125]	validation-rmse:6.55419
# [126]	validation-rmse:6.55384
# [127]	validation-rmse:6.55353
# [128]	validation-rmse:6.55306
# [129]	validation-rmse:6.55259
# [130]	validation-rmse:6.55236
# [131]	validation-rmse:6.55218
# [132]	validation-rmse:6.55170
# [133]	validation-rmse:6.55154
# [134]	validation-rmse:6.55124
# [135]	validation-rmse:6.55082
# [136]	validation-rmse:6.55033
# [137]	validation-rmse:6.55004
# [138]	validation-rmse:6.54947
# [139]	validation-rmse:6.54895
# [140]	validation-rmse:6.54864
# [141]	validation-rmse:6.54815
# [142]	validation-rmse:6.54795
# [143]	validation-rmse:6.54769
# [144]	validation-rmse:6.54734
# [145]	validation-rmse:6.54710
# [146]	validation-rmse:6.54685
# [147]	validation-rmse:6.54676
# [148]	validation-rmse:6.54654
# [149]	validation-rmse:6.54628
# [150]	validation-rmse:6.54598
# [151]	validation-rmse:6.54564
# [152]	validation-rmse:6.54527
# [153]	validation-rmse:6.54507
# [154]	validation-rmse:6.54467
# [155]	validation-rmse:6.54448
# [156]	validation-rmse:6.54421
# [157]	validation-rmse:6.54396
# [158]	validation-rmse:6.54362
# [159]	validation-rmse:6.54339
# [160]	validation-rmse:6.54318
# [161]	validation-rmse:6.54265
# [162]	validation-rmse:6.54240
# [163]	validation-rmse:6.54211
# [164]	validation-rmse:6.54179
# [165]	validation-rmse:6.54156
# [166]	validation-rmse:6.54109
# [167]	validation-rmse:6.54081
# [168]	validation-rmse:6.54058
# [169]	validation-rmse:6.54023
# [170]	validation-rmse:6.54001
# [171]	validation-rmse:6.53973
# [172]	validation-rmse:6.53923
# [173]	validation-rmse:6.53895
# [174]	validation-rmse:6.53883
# [175]	validation-rmse:6.53868
# [176]	validation-rmse:6.53848
# [177]	validation-rmse:6.53821
# [178]	validation-rmse:6.53794
# [179]	validation-rmse:6.53782
# [180]	validation-rmse:6.53751
# [181]	validation-rmse:6.53730
# [182]	validation-rmse:6.53716
# [183]	validation-rmse:6.53683
# [184]	validation-rmse:6.53670
# [185]	validation-rmse:6.53638
# [186]	validation-rmse:6.53613
# [187]	validation-rmse:6.53591
# [188]	validation-rmse:6.53570
# [189]	validation-rmse:6.53543
# [190]	validation-rmse:6.53526
# [191]	validation-rmse:6.53512
# [192]	validation-rmse:6.53466
# [193]	validation-rmse:6.53425
# [194]	validation-rmse:6.53409
# [195]	validation-rmse:6.53379
# [196]	validation-rmse:6.53359
# [197]	validation-rmse:6.53332
# [198]	validation-rmse:6.53325
# [199]	validation-rmse:6.53285
# [200]	validation-rmse:6.53263
# [201]	validation-rmse:6.53240
# [202]	validation-rmse:6.53217
# [203]	validation-rmse:6.53201
# [204]	validation-rmse:6.53169
# [205]	validation-rmse:6.53150
# [206]	validation-rmse:6.53139
# [207]	validation-rmse:6.53117
# [208]	validation-rmse:6.53091
# [209]	validation-rmse:6.53068
# [210]	validation-rmse:6.53058
# [211]	validation-rmse:6.53031
# [212]	validation-rmse:6.53008
# [213]	validation-rmse:6.52976
# [214]	validation-rmse:6.52967
# [215]	validation-rmse:6.52955
# [216]	validation-rmse:6.52938
# [217]	validation-rmse:6.52895
# [218]	validation-rmse:6.52884
# [219]	validation-rmse:6.52851
# [220]	validation-rmse:6.52822
# [221]	validation-rmse:6.52803
# [222]	validation-rmse:6.52784
# [223]	validation-rmse:6.52764
# [224]	validation-rmse:6.52742
# [225]	validation-rmse:6.52717
# [226]	validation-rmse:6.52682
# [227]	validation-rmse:6.52667
# [228]	validation-rmse:6.52654
# [229]	validation-rmse:6.52633
# [230]	validation-rmse:6.52625
# [231]	validation-rmse:6.52619
# [232]	validation-rmse:6.52607
# [233]	validation-rmse:6.52589
# [234]	validation-rmse:6.52574
# [235]	validation-rmse:6.52544
# [236]	validation-rmse:6.52521
# [237]	validation-rmse:6.52498
# [238]	validation-rmse:6.52485
# [239]	validation-rmse:6.52471
# [240]	validation-rmse:6.52448
# [241]	validation-rmse:6.52437
# [242]	validation-rmse:6.52415
# [243]	validation-rmse:6.52375
# [244]	validation-rmse:6.52372
# [245]	validation-rmse:6.52350
# [246]	validation-rmse:6.52324
# [247]	validation-rmse:6.52309
# [248]	validation-rmse:6.52287
# [249]	validation-rmse:6.52269
# [250]	validation-rmse:6.52262
# [251]	validation-rmse:6.52241
# [252]	validation-rmse:6.52226
# [253]	validation-rmse:6.52218
# [254]	validation-rmse:6.52207
# [255]	validation-rmse:6.52195
# [256]	validation-rmse:6.52165
# [257]	validation-rmse:6.52139
# [258]	validation-rmse:6.52116
# [259]	validation-rmse:6.52101
# [260]	validation-rmse:6.52088
# [261]	validation-rmse:6.52074
# [262]	validation-rmse:6.52057
# [263]	validation-rmse:6.52044
# [264]	validation-rmse:6.52023
# [265]	validation-rmse:6.52006
# [266]	validation-rmse:6.52000
# [267]	validation-rmse:6.51978
# [268]	validation-rmse:6.51960
# [269]	validation-rmse:6.51932
# [270]	validation-rmse:6.51919
# [271]	validation-rmse:6.51907
# [272]	validation-rmse:6.51897
# [273]	validation-rmse:6.51879
# [274]	validation-rmse:6.51863
# [275]	validation-rmse:6.51827
# [276]	validation-rmse:6.51816
# [277]	validation-rmse:6.51809
# [278]	validation-rmse:6.51798
# [279]	validation-rmse:6.51777
# [280]	validation-rmse:6.51747
# [281]	validation-rmse:6.51738
# [282]	validation-rmse:6.51718
# [283]	validation-rmse:6.51684
# [284]	validation-rmse:6.51672
# [285]	validation-rmse:6.51649
# [286]	validation-rmse:6.51628
# [287]	validation-rmse:6.51617
# [288]	validation-rmse:6.51598
# [289]	validation-rmse:6.51578
# [290]	validation-rmse:6.51579
# [291]	validation-rmse:6.51565
# [292]	validation-rmse:6.51549
# [293]	validation-rmse:6.51539
# [294]	validation-rmse:6.51533
# [295]	validation-rmse:6.51532
# [296]	validation-rmse:6.51516
# [297]	validation-rmse:6.51500
# [298]	validation-rmse:6.51486
# [299]	validation-rmse:6.51471
# [300]	validation-rmse:6.51444
# [301]	validation-rmse:6.51433
# [302]	validation-rmse:6.51411
# [303]	validation-rmse:6.51396
# [304]	validation-rmse:6.51385
# [305]	validation-rmse:6.51371
# [306]	validation-rmse:6.51356
# [307]	validation-rmse:6.51341
# [308]	validation-rmse:6.51305
# [309]	validation-rmse:6.51295
# [310]	validation-rmse:6.51291
# [311]	validation-rmse:6.51207
# [312]	validation-rmse:6.51193
# [313]	validation-rmse:6.51184
# [314]	validation-rmse:6.51173
# [315]	validation-rmse:6.51158
# [316]	validation-rmse:6.51143
# [317]	validation-rmse:6.51135
# [318]	validation-rmse:6.51126
# [319]	validation-rmse:6.51110
# [320]	validation-rmse:6.51080
# [321]	validation-rmse:6.51079
# [322]	validation-rmse:6.51059
# [323]	validation-rmse:6.51052
# [324]	validation-rmse:6.51048
# [325]	validation-rmse:6.51029
# [326]	validation-rmse:6.51011
# [327]	validation-rmse:6.50950
# [328]	validation-rmse:6.50936
# [329]	validation-rmse:6.50914
# [330]	validation-rmse:6.50900
# [331]	validation-rmse:6.50893
# [332]	validation-rmse:6.50868
# [333]	validation-rmse:6.50867
# [334]	validation-rmse:6.50856
# [335]	validation-rmse:6.50849
# [336]	validation-rmse:6.50843
# [337]	validation-rmse:6.50826
# [338]	validation-rmse:6.50816
# [339]	validation-rmse:6.50803
# [340]	validation-rmse:6.50797
# [341]	validation-rmse:6.50787
# [342]	validation-rmse:6.50780
# [343]	validation-rmse:6.50726
# [344]	validation-rmse:6.50711
# [345]	validation-rmse:6.50702
# [346]	validation-rmse:6.50695
# [347]	validation-rmse:6.50673
# [348]	validation-rmse:6.50660
# [349]	validation-rmse:6.50643
# [350]	validation-rmse:6.50632
# [351]	validation-rmse:6.50616
# [352]	validation-rmse:6.50600
# [353]	validation-rmse:6.50586
# [354]	validation-rmse:6.50573
# [355]	validation-rmse:6.50560
# [356]	validation-rmse:6.50555
# [357]	validation-rmse:6.50549
# [358]	validation-rmse:6.50537
# [359]	validation-rmse:6.50534
# [360]	validation-rmse:6.50524
# [361]	validation-rmse:6.50513
# [362]	validation-rmse:6.50504
# [363]	validation-rmse:6.50482
# [364]	validation-rmse:6.50441
# [365]	validation-rmse:6.50428
# [366]	validation-rmse:6.50407
# [367]	validation-rmse:6.50404
# [368]	validation-rmse:6.50391
# [369]	validation-rmse:6.50374
# [370]	validation-rmse:6.50357
# [371]	validation-rmse:6.50336
# [372]	validation-rmse:6.50333
# [373]	validation-rmse:6.50320
# [374]	validation-rmse:6.50316
# [375]	validation-rmse:6.50304
# [376]	validation-rmse:6.50291
# [377]	validation-rmse:6.50280
# [378]	validation-rmse:6.50278
# [379]	validation-rmse:6.50265
# [380]	validation-rmse:6.50257
# [381]	validation-rmse:6.50236
# [382]	validation-rmse:6.50218
# [383]	validation-rmse:6.50201
# [384]	validation-rmse:6.50191
# [385]	validation-rmse:6.50182
# [386]	validation-rmse:6.50147
# [387]	validation-rmse:6.50054
# [388]	validation-rmse:6.50042
# [389]	validation-rmse:6.50032
# [390]	validation-rmse:6.50028
# [391]	validation-rmse:6.50025
# [392]	validation-rmse:6.50007
# [393]	validation-rmse:6.49997
# [394]	validation-rmse:6.49988
# [395]	validation-rmse:6.49992
# [396]	validation-rmse:6.49970
# [397]	validation-rmse:6.49962
# [398]	validation-rmse:6.49943
# [399]	validation-rmse:6.49934
# [400]	validation-rmse:6.49925
# [401]	validation-rmse:6.49912
# [402]	validation-rmse:6.49899
# [403]	validation-rmse:6.49892
# [404]	validation-rmse:6.49878
# [405]	validation-rmse:6.49850
# [406]	validation-rmse:6.49845
# [407]	validation-rmse:6.49841
# [408]	validation-rmse:6.49827
# [409]	validation-rmse:6.49819
# [410]	validation-rmse:6.49812
# [411]	validation-rmse:6.49801
# [412]	validation-rmse:6.49795
# [413]	validation-rmse:6.49784
# [414]	validation-rmse:6.49778
# [415]	validation-rmse:6.49768
# [416]	validation-rmse:6.49764
# [417]	validation-rmse:6.49760
# [418]	validation-rmse:6.49749
# [419]	validation-rmse:6.49730
# [420]	validation-rmse:6.49719
# [421]	validation-rmse:6.49708
# [422]	validation-rmse:6.49695
# [423]	validation-rmse:6.49695
# [424]	validation-rmse:6.49685
# [425]	validation-rmse:6.49672
# [426]	validation-rmse:6.49666
# [427]	validation-rmse:6.49659
# [428]	validation-rmse:6.49653
# [429]	validation-rmse:6.49648
# [430]	validation-rmse:6.49637
# [431]	validation-rmse:6.49632
# [432]	validation-rmse:6.49621
# [433]	validation-rmse:6.49611
# [434]	validation-rmse:6.49598
# [435]	validation-rmse:6.49599
# [436]	validation-rmse:6.49598
# [437]	validation-rmse:6.49590
# [438]	validation-rmse:6.49581
# [439]	validation-rmse:6.49565
# [440]	validation-rmse:6.49551
# [441]	validation-rmse:6.49544
# [442]	validation-rmse:6.49537
# [443]	validation-rmse:6.49534
# [444]	validation-rmse:6.49528
# [445]	validation-rmse:6.49523
# [446]	validation-rmse:6.49516
# [447]	validation-rmse:6.49513
# [448]	validation-rmse:6.49505
# [449]	validation-rmse:6.49498
# [450]	validation-rmse:6.49477
# [451]	validation-rmse:6.49465
# [452]	validation-rmse:6.49404
# [453]	validation-rmse:6.49318
# [454]	validation-rmse:6.49305
# [455]	validation-rmse:6.49292
# [456]	validation-rmse:6.49282
# [457]	validation-rmse:6.49274
# [458]	validation-rmse:6.49268
# [459]	validation-rmse:6.49260
# [460]	validation-rmse:6.49253
# [461]	validation-rmse:6.49244
# [462]	validation-rmse:6.49227
# [463]	validation-rmse:6.49215
# [464]	validation-rmse:6.49207
# [465]	validation-rmse:6.49208
# [466]	validation-rmse:6.49192
# [467]	validation-rmse:6.49183
# [468]	validation-rmse:6.49174
# [469]	validation-rmse:6.49162
# [470]	validation-rmse:6.49153
# [471]	validation-rmse:6.49147
# [472]	validation-rmse:6.49140
# [473]	validation-rmse:6.49139
# [474]	validation-rmse:6.49133
# [475]	validation-rmse:6.49125
# [476]	validation-rmse:6.49117
# [477]	validation-rmse:6.49117
# [478]	validation-rmse:6.49105
# [479]	validation-rmse:6.49100
# [480]	validation-rmse:6.49091
# [481]	validation-rmse:6.49065
# [482]	validation-rmse:6.49031
# [483]	validation-rmse:6.49026
# [484]	validation-rmse:6.49013
# [485]	validation-rmse:6.49013
# [486]	validation-rmse:6.49009
# [487]	validation-rmse:6.49006
# [488]	validation-rmse:6.49005
# [489]	validation-rmse:6.49001
# [490]	validation-rmse:6.48991
# [491]	validation-rmse:6.48986
# [492]	validation-rmse:6.48982
# [493]	validation-rmse:6.48979
# [494]	validation-rmse:6.48974
# [495]	validation-rmse:6.48971
# [496]	validation-rmse:6.48968
# [497]	validation-rmse:6.48956
# [498]	validation-rmse:6.48949
# [499]	validation-rmse:6.48946
# [500]	validation-rmse:6.48917
# [501]	validation-rmse:6.48847
# [502]	validation-rmse:6.48774
# [503]	validation-rmse:6.48734
# [504]	validation-rmse:6.48729
# ...
# [23]	validation-rmse:6.76711
# [24]	validation-rmse:6.75115
# [25]	validation-rmse:6.73807
# [26]	validation-rmse:6.72652
# [27]	validation-rmse:6.71628
# [28]	validation-rmse:6.70748
# [29]	validation-rmse:6.69973
# [30]	validation-rmse:6.69313
# [31]	validation-rmse:6.68627
# [32]	validation-rmse:6.68084
# [33]	validation-rmse:6.67556
# [34]	validation-rmse:6.67079
# [35]	validation-rmse:6.66641
# [36]	validation-rmse:6.66283
# [37]	validation-rmse:6.65963
# [38]	validation-rmse:6.65649
# [39]	validation-rmse:6.65317
# [40]	validation-rmse:6.65061
# [41]	validation-rmse:6.64803
# [42]	validation-rmse:6.64562
# [43]	validation-rmse:6.64365
# [44]	validation-rmse:6.64133
# [45]	validation-rmse:6.63967
# [46]	validation-rmse:6.63816
# [47]	validation-rmse:6.63687
# [48]	validation-rmse:6.63493
# [49]	validation-rmse:6.63389
# [50]	validation-rmse:6.63273
# [51]	validation-rmse:6.63167
# [52]	validation-rmse:6.63099
# [53]	validation-rmse:6.63037
# [54]	validation-rmse:6.62886
# [55]	validation-rmse:6.62842
# [56]	validation-rmse:6.62800
# [57]	validation-rmse:6.62733
# [58]	validation-rmse:6.62655
# [59]	validation-rmse:6.62602
# [60]	validation-rmse:6.62551
# [61]	validation-rmse:6.62507
# [62]	validation-rmse:6.62465
# [63]	validation-rmse:6.62409
# [64]	validation-rmse:6.62328
# [65]	validation-rmse:6.62279
# [66]	validation-rmse:6.62224
# [67]	validation-rmse:6.62170
# [68]	validation-rmse:6.62132
# [69]	validation-rmse:6.62100
# [70]	validation-rmse:6.62058
# [71]	validation-rmse:6.62019
# [72]	validation-rmse:6.61966
# [73]	validation-rmse:6.61926
# [74]	validation-rmse:6.61879
# [75]	validation-rmse:6.61807
# [76]	validation-rmse:6.61773
# [77]	validation-rmse:6.61703
# [78]	validation-rmse:6.61637
# [79]	validation-rmse:6.61622
# [80]	validation-rmse:6.61587
# [81]	validation-rmse:6.61561
# [82]	validation-rmse:6.61531
# [83]	validation-rmse:6.61512
# [84]	validation-rmse:6.61454
# [85]	validation-rmse:6.61400
# [86]	validation-rmse:6.61365
# [87]	validation-rmse:6.61300
# [88]	validation-rmse:6.61266
# [89]	validation-rmse:6.61215
# [90]	validation-rmse:6.61198
# [91]	validation-rmse:6.61166
# [92]	validation-rmse:6.61107
# [93]	validation-rmse:6.61078
# [94]	validation-rmse:6.61041
# [95]	validation-rmse:6.61008
# [96]	validation-rmse:6.60939
# [97]	validation-rmse:6.60915
# [98]	validation-rmse:6.60891
# [99]	validation-rmse:6.60827
# [100]	validation-rmse:6.60808
# [101]	validation-rmse:6.60762
# [102]	validation-rmse:6.60712
# [103]	validation-rmse:6.60685
# [104]	validation-rmse:6.60621
# [105]	validation-rmse:6.60597
# [106]	validation-rmse:6.60576
# [107]	validation-rmse:6.60511
# [108]	validation-rmse:6.60491
# [109]	validation-rmse:6.60473
# [110]	validation-rmse:6.60455
# [111]	validation-rmse:6.60442
# [112]	validation-rmse:6.60427
# [113]	validation-rmse:6.60384
# [114]	validation-rmse:6.60371
# [115]	validation-rmse:6.60326
# [116]	validation-rmse:6.60284
# [117]	validation-rmse:6.60271
# [118]	validation-rmse:6.60211
# [119]	validation-rmse:6.60186
# [120]	validation-rmse:6.60147
# [121]	validation-rmse:6.60127
# [122]	validation-rmse:6.60114
# [123]	validation-rmse:6.60075
# [124]	validation-rmse:6.60063
# [125]	validation-rmse:6.60052
# [126]	validation-rmse:6.60004
# [127]	validation-rmse:6.59992
# [128]	validation-rmse:6.59967
# [129]	validation-rmse:6.59961
# [130]	validation-rmse:6.59951
# [131]	validation-rmse:6.59900
# [132]	validation-rmse:6.59888
# [133]	validation-rmse:6.59872
#  30%|███       | 3/10 [20:08<46:59, 402.85s/trial, best loss: 6.328857455927513]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 11
#       1 search_space = {
#       2     'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
#       3     'learning_rate': hp.loguniform('learning_rate', -3, 0),
#    (...)
#       8     'seed': 42,
#       9 }
# ---> 11 best_result = fmin(
#      12     fn=objective,
#      13     space=search_space,
#      14     algo=tpe.suggest,
#      15     max_evals=10,
#      16     trials=Trials()
#      17 )
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:540, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     537     fn = __objective_fmin_wrapper(fn)
#     539 if allow_trials_fmin and hasattr(trials, "fmin"):
# --> 540     return trials.fmin(
#     541         fn,
#     542         space,
#     543         algo=algo,
#     544         max_evals=max_evals,
#     545         timeout=timeout,
#     546         loss_threshold=loss_threshold,
#     547         max_queue_len=max_queue_len,
#     548         rstate=rstate,
#     549         pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     550         verbose=verbose,
#     551         catch_eval_exceptions=catch_eval_exceptions,
#     552         return_argmin=return_argmin,
#     553         show_progressbar=show_progressbar,
#     554         early_stop_fn=early_stop_fn,
#     555         trials_save_file=trials_save_file,
#     556     )
#     558 if trials is None:
#     559     if os.path.exists(trials_save_file):
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:671, in Trials.fmin(self, fn, space, algo, max_evals, timeout, loss_threshold, max_queue_len, rstate, verbose, pass_expr_memo_ctrl, catch_eval_exceptions, return_argmin, show_progressbar, early_stop_fn, trials_save_file)
#     666 # -- Stop-gap implementation!
#     667 #    fmin should have been a Trials method in the first place
#     668 #    but for now it's still sitting in another file.
#     669 from .fmin import fmin
# --> 671 return fmin(
#     672     fn,
#     673     space,
#     674     algo=algo,
#     675     max_evals=max_evals,
#     676     timeout=timeout,
#     677     loss_threshold=loss_threshold,
#     678     trials=self,
#     679     rstate=rstate,
#     680     verbose=verbose,
#     681     max_queue_len=max_queue_len,
#     682     allow_trials_fmin=False,  # -- prevent recursion
#     683     pass_expr_memo_ctrl=pass_expr_memo_ctrl,
#     684     catch_eval_exceptions=catch_eval_exceptions,
#     685     return_argmin=return_argmin,
#     686     show_progressbar=show_progressbar,
#     687     early_stop_fn=early_stop_fn,
#     688     trials_save_file=trials_save_file,
#     689 )
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# Cell In[37], line 5, in objective(params)
#       3 mlflow.set_tag("model", "xgboost")
#       4 mlflow.log_params(params)
# ----> 5 booster = xgb.train(
#       6     params=params,
#       7     dtrain=train,
#       8     num_boost_round=1000,
#       9     evals=[(valid, 'validation')],
#      10     early_stopping_rounds=50
#      11 )
#      12 y_pred = booster.predict(valid)
#      13 mse = mean_squared_error(y_val, y_pred) #, squared=False)
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:726, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     724 for k, arg in zip(sig.parameters, args):
#     725     kwargs[k] = arg
# --> 726 return func(**kwargs)
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, iteration=i, fobj=obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~/.pyenv/versions/3.9/envs/exp-tracking-env/lib/python3.9/site-packages/xgboost/core.py:2101, in Booster.update(self, dtrain, iteration, fobj)
#    2097 self._assign_dmatrix_features(dtrain)
#    2099 if fobj is None:
#    2100     _check_call(
# -> 2101         _LIB.XGBoosterUpdateOneIter(
#    2102             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2103         )
#    2104     )
#    2105 else:
#    2106     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:

# %%
params = {
    'learning_rate': 0.5007497542674484,
    'max_depth': 69,
    'min_child_weight': 1.593971756791148,
    'objective': 'reg:linear',
    'reg_alpha': 0.05449929909264596,
    'reg_lambda': 0.34077893742416615,
    'seed': 42
}

mlflow.xgboost.autolog()

booster = xgb.train(
    params=params,
    dtrain=train,
    num_boost_round=1000,
    evals=[(valid, 'validation')],
    early_stopping_rounds=50
)
# Out:
# 2024/12/25 21:10:49 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '8bce676a00b042de963a6dd6ed448991', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current xgboost workflow
# [0]	validation-rmse:8.49781
# [1]	validation-rmse:7.17193
# [2]	validation-rmse:6.73345
# [3]	validation-rmse:6.57592
# [4]	validation-rmse:6.50861
# [5]	validation-rmse:6.48066
# [6]	validation-rmse:6.45617
# [7]	validation-rmse:6.44290
# [8]	validation-rmse:6.43776
# [9]	validation-rmse:6.43271
# [10]	validation-rmse:6.42896
# [11]	validation-rmse:6.42452
# [12]	validation-rmse:6.41868
# [13]	validation-rmse:6.41488
# [14]	validation-rmse:6.41052
# [15]	validation-rmse:6.40751
# [16]	validation-rmse:6.40484
# [17]	validation-rmse:6.40347
# [18]	validation-rmse:6.39845
# [19]	validation-rmse:6.39603
# [20]	validation-rmse:6.39398
# [21]	validation-rmse:6.39171
# [22]	validation-rmse:6.38840
# [23]	validation-rmse:6.38623
# [24]	validation-rmse:6.38325
# [25]	validation-rmse:6.38065
# [26]	validation-rmse:6.37983
# [27]	validation-rmse:6.37647
# [28]	validation-rmse:6.37435
# [29]	validation-rmse:6.37246
# [30]	validation-rmse:6.36992
# [31]	validation-rmse:6.36800
# [32]	validation-rmse:6.36687
# [33]	validation-rmse:6.36443
# [34]	validation-rmse:6.36390
# [35]	validation-rmse:6.36270
# [36]	validation-rmse:6.36050
# [37]	validation-rmse:6.35912
# [38]	validation-rmse:6.35612
# [39]	validation-rmse:6.35566
# [40]	validation-rmse:6.35496
# [41]	validation-rmse:6.35350
# [42]	validation-rmse:6.35169
# [43]	validation-rmse:6.34957
# [44]	validation-rmse:6.34842
# [45]	validation-rmse:6.34771
# [46]	validation-rmse:6.34538
# [47]	validation-rmse:6.34478
# [48]	validation-rmse:6.34384
# [49]	validation-rmse:6.34376
# [50]	validation-rmse:6.34314
# [51]	validation-rmse:6.34271
# [52]	validation-rmse:6.34276
# [53]	validation-rmse:6.34183
# [54]	validation-rmse:6.34066
# [55]	validation-rmse:6.33976
# [56]	validation-rmse:6.34000
# [57]	validation-rmse:6.33742
# [58]	validation-rmse:6.33537
# [59]	validation-rmse:6.33508
# [60]	validation-rmse:6.33459
# [61]	validation-rmse:6.33383
# [62]	validation-rmse:6.33196
# [63]	validation-rmse:6.33068
# [64]	validation-rmse:6.33088
# [65]	validation-rmse:6.33078
# [66]	validation-rmse:6.33060
# [67]	validation-rmse:6.33062
# [68]	validation-rmse:6.33000
# [69]	validation-rmse:6.32937
# [70]	validation-rmse:6.32872
# [71]	validation-rmse:6.32617
# [72]	validation-rmse:6.32688
# [73]	validation-rmse:6.32690
# [74]	validation-rmse:6.32665
# [75]	validation-rmse:6.32665
# [76]	validation-rmse:6.32656
# [77]	validation-rmse:6.32592
# [78]	validation-rmse:6.32479
# [79]	validation-rmse:6.32432
# [80]	validation-rmse:6.32358
# [81]	validation-rmse:6.32274
# [82]	validation-rmse:6.32222
# [83]	validation-rmse:6.32271
# [84]	validation-rmse:6.32343
# [85]	validation-rmse:6.32325
# [86]	validation-rmse:6.32319
# [87]	validation-rmse:6.32222
# [88]	validation-rmse:6.32078
# [89]	validation-rmse:6.32156
# [90]	validation-rmse:6.32173
# [91]	validation-rmse:6.32184
# [92]	validation-rmse:6.32155
# [93]	validation-rmse:6.32158
# [94]	validation-rmse:6.32100
# [95]	validation-rmse:6.32249
# [96]	validation-rmse:6.32254
# [97]	validation-rmse:6.32250
# [98]	validation-rmse:6.32354
# [99]	validation-rmse:6.32351
# [100]	validation-rmse:6.32300
# [101]	validation-rmse:6.32381
# [102]	validation-rmse:6.32351
# [103]	validation-rmse:6.32404
# [104]	validation-rmse:6.32216
# [105]	validation-rmse:6.32233
# [106]	validation-rmse:6.32264
# [107]	validation-rmse:6.32249
# [108]	validation-rmse:6.32232
# [109]	validation-rmse:6.32240
# [110]	validation-rmse:6.32331
# [111]	validation-rmse:6.32421
# [112]	validation-rmse:6.32505
# [113]	validation-rmse:6.32563
# [114]	validation-rmse:6.32589
# [115]	validation-rmse:6.32548
# [116]	validation-rmse:6.32506
# [117]	validation-rmse:6.32503
# [118]	validation-rmse:6.32600
# [119]	validation-rmse:6.32596
# [120]	validation-rmse:6.32654
# [121]	validation-rmse:6.32666
# [122]	validation-rmse:6.32762
# [123]	validation-rmse:6.32736
# [124]	validation-rmse:6.32764
# [125]	validation-rmse:6.32724
# [126]	validation-rmse:6.32708
# [127]	validation-rmse:6.32720
# [128]	validation-rmse:6.32751
# [129]	validation-rmse:6.32878
# [130]	validation-rmse:6.32882
# [131]	validation-rmse:6.32934
# [132]	validation-rmse:6.32918
# [133]	validation-rmse:6.32896
# [134]	validation-rmse:6.32922
# [135]	validation-rmse:6.32903
# [136]	validation-rmse:6.32835
# [137]	validation-rmse:6.32837
# [138]	validation-rmse:6.32886
# 2024/12/25 21:19:35 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.
# 2024/12/25 21:19:53 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
mlflow.xgboost.autolog(disable=True)

# %%
with mlflow.start_run():

    train = xgb.DMatrix(X_train, label=y_train)
    valid = xgb.DMatrix(X_val, label=y_val)

    best_params = {
        'learning_rate': 0.5007497542674484,
        'max_depth': 69,
        'min_child_weight': 1.593971756791148,
        'objective': 'reg:linear',
        'reg_alpha': 0.05449929909264596,
        'reg_lambda': 0.34077893742416615,
        'seed': 42
    }

    mlflow.log_params(best_params)

    booster = xgb.train(
        params=best_params,
        dtrain=train,
        num_boost_round=1000,
        evals=[(valid, 'validation')],
        early_stopping_rounds=50
    )

    y_pred = booster.predict(valid)

    mse = mean_squared_error(y_val, y_pred) #, squared=False)
    rmse = np.sqrt(mse)
    mlflow.log_metric("rmse", rmse)


    with open('models/preprocessor.b', 'wb') as f_out:
        pickle.dump(dv, f_out)

    mlflow.log_artifact("models/preprocessor.b", artifact_path='preprocessor')
    mlflow.xgboost.log_model(booster, artifact_path='models_mlflow')
# Out:
# [0]	validation-rmse:8.49781
# [1]	validation-rmse:7.17193
# [2]	validation-rmse:6.73345
# [3]	validation-rmse:6.57592
# [4]	validation-rmse:6.50861
# [5]	validation-rmse:6.48066
# [6]	validation-rmse:6.45617
# [7]	validation-rmse:6.44290
# [8]	validation-rmse:6.43776
# [9]	validation-rmse:6.43271
# [10]	validation-rmse:6.42896
# [11]	validation-rmse:6.42452
# [12]	validation-rmse:6.41868
# [13]	validation-rmse:6.41488
# [14]	validation-rmse:6.41052
# [15]	validation-rmse:6.40751
# [16]	validation-rmse:6.40484
# [17]	validation-rmse:6.40347
# [18]	validation-rmse:6.39845
# [19]	validation-rmse:6.39603
# [20]	validation-rmse:6.39398
# [21]	validation-rmse:6.39171
# [22]	validation-rmse:6.38840
# [23]	validation-rmse:6.38623
# [24]	validation-rmse:6.38325
# [25]	validation-rmse:6.38065
# [26]	validation-rmse:6.37983
# [27]	validation-rmse:6.37647
# [28]	validation-rmse:6.37435
# [29]	validation-rmse:6.37246
# [30]	validation-rmse:6.36992
# [31]	validation-rmse:6.36800
# [32]	validation-rmse:6.36687
# [33]	validation-rmse:6.36443
# [34]	validation-rmse:6.36390
# [35]	validation-rmse:6.36270
# [36]	validation-rmse:6.36050
# [37]	validation-rmse:6.35912
# [38]	validation-rmse:6.35612
# [39]	validation-rmse:6.35566
# [40]	validation-rmse:6.35496
# [41]	validation-rmse:6.35350
# [42]	validation-rmse:6.35169
# [43]	validation-rmse:6.34957
# [44]	validation-rmse:6.34842
# [45]	validation-rmse:6.34771
# [46]	validation-rmse:6.34538
# [47]	validation-rmse:6.34478
# [48]	validation-rmse:6.34384
# [49]	validation-rmse:6.34376
# [50]	validation-rmse:6.34314
# [51]	validation-rmse:6.34271
# [52]	validation-rmse:6.34276
# [53]	validation-rmse:6.34183
# [54]	validation-rmse:6.34066
# [55]	validation-rmse:6.33976
# [56]	validation-rmse:6.34000
# [57]	validation-rmse:6.33742
# [58]	validation-rmse:6.33537
# [59]	validation-rmse:6.33508
# [60]	validation-rmse:6.33459
# [61]	validation-rmse:6.33383
# [62]	validation-rmse:6.33196
# [63]	validation-rmse:6.33068
# [64]	validation-rmse:6.33088
# [65]	validation-rmse:6.33078
# [66]	validation-rmse:6.33060
# [67]	validation-rmse:6.33062
# [68]	validation-rmse:6.33000
# [69]	validation-rmse:6.32937
# [70]	validation-rmse:6.32872
# [71]	validation-rmse:6.32617
# [72]	validation-rmse:6.32688
# [73]	validation-rmse:6.32690
# [74]	validation-rmse:6.32665
# [75]	validation-rmse:6.32665
# [76]	validation-rmse:6.32656
# [77]	validation-rmse:6.32592
# [78]	validation-rmse:6.32479
# [79]	validation-rmse:6.32432
# [80]	validation-rmse:6.32358
# [81]	validation-rmse:6.32274
# [82]	validation-rmse:6.32222
# [83]	validation-rmse:6.32271
# [84]	validation-rmse:6.32343
# [85]	validation-rmse:6.32325
# [86]	validation-rmse:6.32319
# [87]	validation-rmse:6.32222
# [88]	validation-rmse:6.32078
# [89]	validation-rmse:6.32156
# [90]	validation-rmse:6.32173
# [91]	validation-rmse:6.32184
# [92]	validation-rmse:6.32155
# [93]	validation-rmse:6.32158
# [94]	validation-rmse:6.32100
# [95]	validation-rmse:6.32249
# [96]	validation-rmse:6.32254
# [97]	validation-rmse:6.32250
# [98]	validation-rmse:6.32354
# [99]	validation-rmse:6.32351
# [100]	validation-rmse:6.32300
# [101]	validation-rmse:6.32381
# [102]	validation-rmse:6.32351
# [103]	validation-rmse:6.32404
# [104]	validation-rmse:6.32216
# [105]	validation-rmse:6.32233
# [106]	validation-rmse:6.32264
# [107]	validation-rmse:6.32249
# [108]	validation-rmse:6.32232
# [109]	validation-rmse:6.32240
# [110]	validation-rmse:6.32331
# [111]	validation-rmse:6.32421
# [112]	validation-rmse:6.32505
# [113]	validation-rmse:6.32563
# [114]	validation-rmse:6.32589
# [115]	validation-rmse:6.32548
# [116]	validation-rmse:6.32506
# [117]	validation-rmse:6.32503
# [118]	validation-rmse:6.32600
# [119]	validation-rmse:6.32596
# [120]	validation-rmse:6.32654
# [121]	validation-rmse:6.32666
# [122]	validation-rmse:6.32762
# [123]	validation-rmse:6.32736
# [124]	validation-rmse:6.32764
# [125]	validation-rmse:6.32724
# [126]	validation-rmse:6.32708
# [127]	validation-rmse:6.32720
# [128]	validation-rmse:6.32751
# [129]	validation-rmse:6.32878
# [130]	validation-rmse:6.32882
# [131]	validation-rmse:6.32934
# [132]	validation-rmse:6.32918
# [133]	validation-rmse:6.32896
# [134]	validation-rmse:6.32922
# [135]	validation-rmse:6.32903
# [136]	validation-rmse:6.32835
# [137]	validation-rmse:6.32837
# 2024/12/25 22:14:48 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
logged_model = 'runs:/b4e5d303ed394f9ebceb9db15ca3a4d2/models_mlflow'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# %%
# Predict on a Pandas DataFrame.
loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: models_mlflow
#   flavor: mlflow.xgboost
#   run_id: b4e5d303ed394f9ebceb9db15ca3a4d2

# %%
xgboost_model = mlflow.xgboost.load_model(logged_model)

# %%
xgboost_model.predict(valid)

# %%
y_pred = xgboost_model.predict(valid)

# %%
y_pred[:10]
# Out:
# array([14.055848 ,  6.5770626, 13.076859 , 24.574144 ,  9.397497 ,
#        17.068619 , 10.59555  ,  7.685579 ,  8.997662 , 15.680276 ],
#       dtype=float32)
